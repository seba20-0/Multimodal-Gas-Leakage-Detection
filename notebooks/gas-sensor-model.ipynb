# %%
import os, glob
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

def load_and_split_sensor_data(
    csv_path: str,
    test_size: float = 0.1,
    val_size: float = 0.2,
    random_state: int = 42
):
    """
    Load sensor CSV, preprocess (drop columns, encode labels, scale), and split into train/val/test.

    Args:
        csv_path: Path to the Gas Sensors Measurements CSV file.
        test_size: Fraction of data reserved for final test set.
        val_size: Fraction of remaining data reserved for validation.
        random_state: Random seed for reproducibility.

    Returns:
        train_ds: tf.data.Dataset for training (features, labels).
        val_ds: tf.data.Dataset for validation.
        test_ds: tf.data.Dataset for testing.
    """
    # 1) Load and clean
    df = pd.read_csv(csv_path)
    # drop unused columns
    df = df.drop(columns=["Serial Number", "Corresponding Image Name"], errors='ignore')
    # encode labels
    df['Gas'] = df['Gas'].astype('category').cat.codes

    # 2) Extract features and labels
    feature_cols = [c for c in df.columns if c != 'Gas']
    X = df[feature_cols].values.astype('float32')
    y = df['Gas'].values.astype('int32')

    # 3) Scale features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # 4) Split into train+val and test
    X_temp, X_test, y_temp, y_test = train_test_split(
        X_scaled, y, test_size=test_size, stratify=y, random_state=random_state
    )
    # Split train_temp into train and val
    val_fraction = val_size / (1 - test_size)
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=val_fraction,
        stratify=y_temp, random_state=random_state
    )

    # 5) Build tf.data datasets
    def make_ds(features, labels, batch_size=32, shuffle=False):
        ds = tf.data.Dataset.from_tensor_slices((features, labels))
        if shuffle:
            ds = ds.shuffle(buffer_size=len(features), seed=random_state)
        return ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    batch_size = 32
    train_ds = make_ds(X_train, y_train, batch_size, shuffle=True)
    val_ds   = make_ds(X_val,   y_val,   batch_size, shuffle=False)
    test_ds  = make_ds(X_test,  y_test,  batch_size, shuffle=False)

    return train_ds, val_ds, test_ds
# Out:
# 2025-05-05 00:04:42.336633: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746403482.658573      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746403482.773912      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
train_ds, val_ds, test_ds = load_and_split_sensor_data("../dataset/Gas Sensors Measurements/Gas_Sensors_Measurements.csv")
# Out:
# 2025-05-05 00:04:59.711109: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
class RandomSensorDropout(tf.keras.layers.Layer):
    """
    Layer that randomly zeros individual sensor channels with a given rate during training.
    Supports proper serialization.
    """
    def __init__(self, rate=0.3, **kwargs):
        super().__init__(**kwargs)
        self.rate = rate

    def call(self, inputs, training=False):
        if training and self.rate > 0.0:
            mask = tf.cast(tf.random.uniform(tf.shape(inputs)) > self.rate, inputs.dtype)
            return inputs * mask
        return inputs

    def get_config(self):
        config = super().get_config()
        config.update({"rate": self.rate})
        return config
        
def build_sensor_model(
    input_dim=7,
    sensor_dropout_rate=0.3,
    layer_dropout = 0.5,
    hidden_units=(64, 32),
    output_units=4,
    lr=1e-4
):
    """
    Sensor-only MLP with RandomSensorDropout option for ablation.
    """
    inp = tf.keras.Input(shape=(input_dim,), name="sensor_input")
    x = RandomSensorDropout(sensor_dropout_rate, name="sensor_dropout")(inp)
    x = tf.keras.layers.Dense(hidden_units[0], activation="relu")(x)
    x = tf.keras.layers.Dropout(layer_dropout)(x)
    x = tf.keras.layers.Dense(hidden_units[1], activation="relu")(x)
    x = tf.keras.layers.Dropout(layer_dropout)(x)
    out = tf.keras.layers.Dense(output_units, activation="softmax", name="output")(x)

    model = tf.keras.Model(inp, out, name="sensor_only")
    model.compile(
        optimizer=tf.keras.optimizers.Adam(lr),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %%
model = build_sensor_model()
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_sensor_model.keras', monitor='val_accuracy',
    save_best_only=True, mode='max', verbose=1
)
history = model.fit(train_ds,
                    validation_data=val_ds,
                    epochs=100,
                    batch_size=32, callbacks = [checkpoint])
# Out:
# Epoch 1/100
# 114/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2760 - loss: 1.5917
# Epoch 1: val_accuracy improved from -inf to 0.48359, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.2775 - loss: 1.5854 - val_accuracy: 0.4836 - val_loss: 1.4004
# Epoch 2/100
# 129/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3309 - loss: 1.4363
# Epoch 2: val_accuracy improved from 0.48359 to 0.50156, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3316 - loss: 1.4344 - val_accuracy: 0.5016 - val_loss: 1.2210
# Epoch 3/100
# 125/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3967 - loss: 1.3206
# Epoch 3: val_accuracy improved from 0.50156 to 0.59062, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3983 - loss: 1.3176 - val_accuracy: 0.5906 - val_loss: 1.0601
# Epoch 4/100
# 128/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4690 - loss: 1.2078
# Epoch 4: val_accuracy improved from 0.59062 to 0.73828, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4705 - loss: 1.2059 - val_accuracy: 0.7383 - val_loss: 0.9158
# Epoch 5/100
# 117/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5293 - loss: 1.1174
# Epoch 5: val_accuracy improved from 0.73828 to 0.77578, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5305 - loss: 1.1148 - val_accuracy: 0.7758 - val_loss: 0.7859
# Epoch 6/100
# 125/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5654 - loss: 1.0457
# Epoch 6: val_accuracy improved from 0.77578 to 0.79922, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5664 - loss: 1.0433 - val_accuracy: 0.7992 - val_loss: 0.6829
# Epoch 7/100
# 112/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5969 - loss: 0.9631
# Epoch 7: val_accuracy improved from 0.79922 to 0.80625, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5985 - loss: 0.9606 - val_accuracy: 0.8062 - val_loss: 0.5983
# Epoch 8/100
# 123/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6164 - loss: 0.8929
# Epoch 8: val_accuracy improved from 0.80625 to 0.81719, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6164 - loss: 0.8915 - val_accuracy: 0.8172 - val_loss: 0.5336
# Epoch 9/100
# 115/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6338 - loss: 0.8459
# Epoch 9: val_accuracy improved from 0.81719 to 0.81875, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6339 - loss: 0.8433 - val_accuracy: 0.8188 - val_loss: 0.4859
# Epoch 10/100
# 124/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6495 - loss: 0.7732
# Epoch 10: val_accuracy improved from 0.81875 to 0.82266, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6498 - loss: 0.7731 - val_accuracy: 0.8227 - val_loss: 0.4517
# Epoch 11/100
# 117/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6569 - loss: 0.7492
# Epoch 11: val_accuracy improved from 0.82266 to 0.82734, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6571 - loss: 0.7480 - val_accuracy: 0.8273 - val_loss: 0.4269
# Epoch 12/100
# 138/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6818 - loss: 0.7126
# Epoch 12: val_accuracy did not improve from 0.82734
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6815 - loss: 0.7126 - val_accuracy: 0.8258 - val_loss: 0.4083
# Epoch 13/100
# 133/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6840 - loss: 0.6770
# Epoch 13: val_accuracy did not improve from 0.82734
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6836 - loss: 0.6773 - val_accuracy: 0.8250 - val_loss: 0.3942
# Epoch 14/100
# 129/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6759 - loss: 0.6763
# Epoch 14: val_accuracy did not improve from 0.82734
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6757 - loss: 0.6765 - val_accuracy: 0.8227 - val_loss: 0.3840
# Epoch 15/100
# 135/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6791 - loss: 0.6456
# Epoch 15: val_accuracy improved from 0.82734 to 0.83125, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6792 - loss: 0.6454 - val_accuracy: 0.8313 - val_loss: 0.3751
# Epoch 16/100
# 127/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7042 - loss: 0.6075
# Epoch 16: val_accuracy improved from 0.83125 to 0.83203, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7033 - loss: 0.6089 - val_accuracy: 0.8320 - val_loss: 0.3685
# Epoch 17/100
# 126/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6915 - loss: 0.6258
# Epoch 17: val_accuracy improved from 0.83203 to 0.83359, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6918 - loss: 0.6246 - val_accuracy: 0.8336 - val_loss: 0.3633
# Epoch 18/100
# 125/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6855 - loss: 0.6104
# Epoch 18: val_accuracy improved from 0.83359 to 0.83984, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6859 - loss: 0.6103 - val_accuracy: 0.8398 - val_loss: 0.3591
# Epoch 19/100
# 123/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6908 - loss: 0.6124
# Epoch 19: val_accuracy improved from 0.83984 to 0.84219, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6925 - loss: 0.6103 - val_accuracy: 0.8422 - val_loss: 0.3557
# Epoch 20/100
# 129/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7078 - loss: 0.5760
# Epoch 20: val_accuracy did not improve from 0.84219
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7074 - loss: 0.5760 - val_accuracy: 0.8414 - val_loss: 0.3525
# Epoch 21/100
# 127/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6959 - loss: 0.5972
# Epoch 21: val_accuracy improved from 0.84219 to 0.84531, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6974 - loss: 0.5951 - val_accuracy: 0.8453 - val_loss: 0.3499
# Epoch 22/100
# 119/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6821 - loss: 0.5983
# Epoch 22: val_accuracy did not improve from 0.84531
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6842 - loss: 0.5955 - val_accuracy: 0.8391 - val_loss: 0.3474
# Epoch 23/100
# 133/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7151 - loss: 0.5628
# Epoch 23: val_accuracy improved from 0.84531 to 0.85000, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7150 - loss: 0.5627 - val_accuracy: 0.8500 - val_loss: 0.3452
# Epoch 24/100
# 126/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7270 - loss: 0.5233
# Epoch 24: val_accuracy did not improve from 0.85000
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7266 - loss: 0.5248 - val_accuracy: 0.8500 - val_loss: 0.3434
# Epoch 25/100
# 116/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7248 - loss: 0.5467
# Epoch 25: val_accuracy did not improve from 0.85000
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7236 - loss: 0.5467 - val_accuracy: 0.8492 - val_loss: 0.3416
# Epoch 26/100
# 116/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7114 - loss: 0.5297
# Epoch 26: val_accuracy did not improve from 0.85000
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7122 - loss: 0.5289 - val_accuracy: 0.8469 - val_loss: 0.3398
# Epoch 27/100
# 119/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7205 - loss: 0.5253
# Epoch 27: val_accuracy improved from 0.85000 to 0.86016, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7193 - loss: 0.5264 - val_accuracy: 0.8602 - val_loss: 0.3385
# Epoch 28/100
# 132/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7330 - loss: 0.5183
# Epoch 28: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7323 - loss: 0.5191 - val_accuracy: 0.8578 - val_loss: 0.3373
# Epoch 29/100
# 129/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7258 - loss: 0.5188
# Epoch 29: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7251 - loss: 0.5200 - val_accuracy: 0.8555 - val_loss: 0.3361
# Epoch 30/100
# 127/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7052 - loss: 0.5452
# Epoch 30: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7062 - loss: 0.5440 - val_accuracy: 0.8570 - val_loss: 0.3350
# Epoch 31/100
# 119/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7194 - loss: 0.5103
# Epoch 31: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7195 - loss: 0.5132 - val_accuracy: 0.8586 - val_loss: 0.3345
# Epoch 32/100
# 111/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7336 - loss: 0.5210
# Epoch 32: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7321 - loss: 0.5224 - val_accuracy: 0.8578 - val_loss: 0.3337
# Epoch 33/100
# 123/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7287 - loss: 0.5073
# Epoch 33: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7280 - loss: 0.5086 - val_accuracy: 0.8570 - val_loss: 0.3331
# Epoch 34/100
# 122/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7185 - loss: 0.4990
# Epoch 34: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7177 - loss: 0.5013 - val_accuracy: 0.8562 - val_loss: 0.3322
# Epoch 35/100
# 121/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7389 - loss: 0.5034
# Epoch 35: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7379 - loss: 0.5047 - val_accuracy: 0.8578 - val_loss: 0.3314
# Epoch 36/100
# 120/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7272 - loss: 0.5071
# Epoch 36: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7267 - loss: 0.5071 - val_accuracy: 0.8531 - val_loss: 0.3304
# Epoch 37/100
# 125/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7403 - loss: 0.4953
# Epoch 37: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7394 - loss: 0.4951 - val_accuracy: 0.8523 - val_loss: 0.3298
# Epoch 38/100
# 120/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7365 - loss: 0.5028
# Epoch 38: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7355 - loss: 0.5040 - val_accuracy: 0.8492 - val_loss: 0.3293
# Epoch 39/100
# 120/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7330 - loss: 0.4837
# Epoch 39: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7319 - loss: 0.4859 - val_accuracy: 0.8523 - val_loss: 0.3288
# Epoch 40/100
# 122/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7318 - loss: 0.5028
# Epoch 40: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7311 - loss: 0.5019 - val_accuracy: 0.8539 - val_loss: 0.3283
# Epoch 41/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7252 - loss: 0.4949
# Epoch 41: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7253 - loss: 0.4949 - val_accuracy: 0.8500 - val_loss: 0.3277
# Epoch 42/100
# 118/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7292 - loss: 0.5015
# Epoch 42: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7283 - loss: 0.5020 - val_accuracy: 0.8531 - val_loss: 0.3275
# Epoch 43/100
# 126/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7160 - loss: 0.5078
# Epoch 43: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7177 - loss: 0.5070 - val_accuracy: 0.8492 - val_loss: 0.3270
# Epoch 44/100
# 129/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7156 - loss: 0.5181
# Epoch 44: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7170 - loss: 0.5163 - val_accuracy: 0.8523 - val_loss: 0.3267
# Epoch 45/100
# 130/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7390 - loss: 0.4796
# Epoch 45: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7392 - loss: 0.4797 - val_accuracy: 0.8531 - val_loss: 0.3260
# Epoch 46/100
# 115/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7269 - loss: 0.4894
# Epoch 46: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7285 - loss: 0.4880 - val_accuracy: 0.8539 - val_loss: 0.3253
# Epoch 47/100
# 124/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7389 - loss: 0.4831
# Epoch 47: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7391 - loss: 0.4817 - val_accuracy: 0.8555 - val_loss: 0.3249
# Epoch 48/100
# 118/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7329 - loss: 0.4945
# Epoch 48: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7342 - loss: 0.4916 - val_accuracy: 0.8516 - val_loss: 0.3241
# Epoch 49/100
# 135/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7433 - loss: 0.4684
# Epoch 49: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7431 - loss: 0.4690 - val_accuracy: 0.8586 - val_loss: 0.3238
# Epoch 50/100
# 114/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7440 - loss: 0.4930
# Epoch 50: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7450 - loss: 0.4908 - val_accuracy: 0.8562 - val_loss: 0.3233
# Epoch 51/100
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7437 - loss: 0.4897
# Epoch 51: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7436 - loss: 0.4898 - val_accuracy: 0.8562 - val_loss: 0.3225
# Epoch 52/100
# 118/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7435 - loss: 0.4607
# Epoch 52: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7434 - loss: 0.4617 - val_accuracy: 0.8570 - val_loss: 0.3221
# Epoch 53/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7322 - loss: 0.4797
# Epoch 53: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7322 - loss: 0.4796 - val_accuracy: 0.8547 - val_loss: 0.3216
# Epoch 54/100
# 126/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7357 - loss: 0.4825
# Epoch 54: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7355 - loss: 0.4817 - val_accuracy: 0.8508 - val_loss: 0.3210
# Epoch 55/100
# 117/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7295 - loss: 0.4734
# Epoch 55: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7311 - loss: 0.4732 - val_accuracy: 0.8555 - val_loss: 0.3206
# Epoch 56/100
# 126/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7403 - loss: 0.4628
# Epoch 56: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7398 - loss: 0.4634 - val_accuracy: 0.8492 - val_loss: 0.3203
# Epoch 57/100
# 124/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7406 - loss: 0.4735
# Epoch 57: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7414 - loss: 0.4740 - val_accuracy: 0.8508 - val_loss: 0.3197
# Epoch 58/100
# 122/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7400 - loss: 0.4712
# Epoch 58: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7406 - loss: 0.4707 - val_accuracy: 0.8539 - val_loss: 0.3191
# Epoch 59/100
# 132/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7456 - loss: 0.4625
# Epoch 59: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7456 - loss: 0.4628 - val_accuracy: 0.8555 - val_loss: 0.3194
# Epoch 60/100
# 128/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7373 - loss: 0.4631
# Epoch 60: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7379 - loss: 0.4628 - val_accuracy: 0.8539 - val_loss: 0.3191
# Epoch 61/100
# 122/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7439 - loss: 0.4686
# Epoch 61: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7435 - loss: 0.4691 - val_accuracy: 0.8516 - val_loss: 0.3184
# Epoch 62/100
# 124/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7430 - loss: 0.4878
# Epoch 62: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7429 - loss: 0.4868 - val_accuracy: 0.8500 - val_loss: 0.3181
# Epoch 63/100
# 116/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7422 - loss: 0.4595
# Epoch 63: val_accuracy did not improve from 0.86016
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7426 - loss: 0.4592 - val_accuracy: 0.8555 - val_loss: 0.3176
# Epoch 64/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7354 - loss: 0.4653
# Epoch 64: val_accuracy improved from 0.86016 to 0.86172, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7354 - loss: 0.4653 - val_accuracy: 0.8617 - val_loss: 0.3175
# Epoch 65/100
# 120/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7618 - loss: 0.4604
# Epoch 65: val_accuracy did not improve from 0.86172
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7619 - loss: 0.4609 - val_accuracy: 0.8570 - val_loss: 0.3168
# Epoch 66/100
# 127/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7534 - loss: 0.4657
# Epoch 66: val_accuracy did not improve from 0.86172
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7532 - loss: 0.4649 - val_accuracy: 0.8594 - val_loss: 0.3160
# Epoch 67/100
# 122/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7548 - loss: 0.4578
# Epoch 67: val_accuracy did not improve from 0.86172
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7541 - loss: 0.4593 - val_accuracy: 0.8594 - val_loss: 0.3159
# Epoch 68/100
# 122/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7384 - loss: 0.4837
# Epoch 68: val_accuracy did not improve from 0.86172
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7404 - loss: 0.4809 - val_accuracy: 0.8570 - val_loss: 0.3157
# Epoch 69/100
# 124/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7556 - loss: 0.4610
# Epoch 69: val_accuracy did not improve from 0.86172
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7543 - loss: 0.4612 - val_accuracy: 0.8586 - val_loss: 0.3155
# Epoch 70/100
# 129/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7500 - loss: 0.4787
# Epoch 70: val_accuracy did not improve from 0.86172
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7503 - loss: 0.4780 - val_accuracy: 0.8578 - val_loss: 0.3151
# Epoch 71/100
# 121/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7465 - loss: 0.4645
# Epoch 71: val_accuracy improved from 0.86172 to 0.86250, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7470 - loss: 0.4649 - val_accuracy: 0.8625 - val_loss: 0.3144
# Epoch 72/100
# 126/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7430 - loss: 0.4712
# Epoch 72: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7441 - loss: 0.4698 - val_accuracy: 0.8617 - val_loss: 0.3138
# Epoch 73/100
# 121/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7413 - loss: 0.4693
# Epoch 73: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7440 - loss: 0.4664 - val_accuracy: 0.8594 - val_loss: 0.3136
# Epoch 74/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7619 - loss: 0.4540
# Epoch 74: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7618 - loss: 0.4541 - val_accuracy: 0.8578 - val_loss: 0.3129
# Epoch 75/100
# 125/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7520 - loss: 0.4591
# Epoch 75: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7515 - loss: 0.4598 - val_accuracy: 0.8555 - val_loss: 0.3124
# Epoch 76/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7741 - loss: 0.4440
# Epoch 76: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7740 - loss: 0.4440 - val_accuracy: 0.8547 - val_loss: 0.3124
# Epoch 77/100
# 121/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7549 - loss: 0.4651
# Epoch 77: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7542 - loss: 0.4646 - val_accuracy: 0.8555 - val_loss: 0.3113
# Epoch 78/100
# 116/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7494 - loss: 0.4651
# Epoch 78: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7494 - loss: 0.4628 - val_accuracy: 0.8586 - val_loss: 0.3115
# Epoch 79/100
# 122/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7552 - loss: 0.4469
# Epoch 79: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7558 - loss: 0.4470 - val_accuracy: 0.8562 - val_loss: 0.3113
# Epoch 80/100
# 128/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7600 - loss: 0.4497
# Epoch 80: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7594 - loss: 0.4500 - val_accuracy: 0.8594 - val_loss: 0.3108
# Epoch 81/100
# 119/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7561 - loss: 0.4469
# Epoch 81: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7570 - loss: 0.4464 - val_accuracy: 0.8594 - val_loss: 0.3105
# Epoch 82/100
# 135/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7504 - loss: 0.4662
# Epoch 82: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7506 - loss: 0.4655 - val_accuracy: 0.8594 - val_loss: 0.3097
# Epoch 83/100
# 129/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7658 - loss: 0.4562
# Epoch 83: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7661 - loss: 0.4560 - val_accuracy: 0.8578 - val_loss: 0.3089
# Epoch 84/100
# 127/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7517 - loss: 0.4487
# Epoch 84: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7524 - loss: 0.4487 - val_accuracy: 0.8547 - val_loss: 0.3086
# Epoch 85/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7539 - loss: 0.4462
# Epoch 85: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7539 - loss: 0.4462 - val_accuracy: 0.8570 - val_loss: 0.3083
# Epoch 86/100
# 128/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7487 - loss: 0.4604
# Epoch 86: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7492 - loss: 0.4599 - val_accuracy: 0.8594 - val_loss: 0.3079
# Epoch 87/100
# 117/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7455 - loss: 0.4744
# Epoch 87: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7465 - loss: 0.4726 - val_accuracy: 0.8570 - val_loss: 0.3078
# Epoch 88/100
# 114/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7598 - loss: 0.4798
# Epoch 88: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7604 - loss: 0.4759 - val_accuracy: 0.8609 - val_loss: 0.3073
# Epoch 89/100
# 131/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7646 - loss: 0.4495
# Epoch 89: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7641 - loss: 0.4499 - val_accuracy: 0.8609 - val_loss: 0.3073
# Epoch 90/100
# 134/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7644 - loss: 0.4367
# Epoch 90: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7644 - loss: 0.4367 - val_accuracy: 0.8609 - val_loss: 0.3070
# Epoch 91/100
# 135/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7497 - loss: 0.4599
# Epoch 91: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7496 - loss: 0.4594 - val_accuracy: 0.8594 - val_loss: 0.3069
# Epoch 92/100
# 118/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7634 - loss: 0.4503
# Epoch 92: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7630 - loss: 0.4499 - val_accuracy: 0.8625 - val_loss: 0.3062
# Epoch 93/100
# 117/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7541 - loss: 0.4555
# Epoch 93: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7542 - loss: 0.4542 - val_accuracy: 0.8617 - val_loss: 0.3061
# Epoch 94/100
# 120/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7699 - loss: 0.4226
# Epoch 94: val_accuracy did not improve from 0.86250
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7696 - loss: 0.4245 - val_accuracy: 0.8625 - val_loss: 0.3053
# Epoch 95/100
# 134/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7702 - loss: 0.4402
# Epoch 95: val_accuracy improved from 0.86250 to 0.86328, saving model to best_sensor_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7700 - loss: 0.4402 - val_accuracy: 0.8633 - val_loss: 0.3047
# Epoch 96/100
# 126/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7801 - loss: 0.4251
# Epoch 96: val_accuracy did not improve from 0.86328
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7797 - loss: 0.4261 - val_accuracy: 0.8578 - val_loss: 0.3043
# Epoch 97/100
# 118/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7468 - loss: 0.4602
# Epoch 97: val_accuracy did not improve from 0.86328
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7486 - loss: 0.4585 - val_accuracy: 0.8547 - val_loss: 0.3041
# Epoch 98/100
# 126/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7616 - loss: 0.4239
# Epoch 98: val_accuracy did not improve from 0.86328
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7616 - loss: 0.4254 - val_accuracy: 0.8617 - val_loss: 0.3034
# Epoch 99/100
# 130/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7505 - loss: 0.4510
# Epoch 99: val_accuracy did not improve from 0.86328
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7520 - loss: 0.4500 - val_accuracy: 0.8578 - val_loss: 0.3032
# Epoch 100/100
# 131/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7652 - loss: 0.4405
# Epoch 100: val_accuracy did not improve from 0.86328
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7651 - loss: 0.4404 - val_accuracy: 0.8602 - val_loss: 0.3032

# %%
model = tf.keras.models.load_model('best_sensor_model.keras',custom_objects={"RandomSensorDropout": RandomSensorDropout})
test_loss, test_accuracy = model.evaluate(test_ds, verbose=0)
print("test accuracy is ", test_accuracy)
# Out:
# test accuracy is  0.871874988079071

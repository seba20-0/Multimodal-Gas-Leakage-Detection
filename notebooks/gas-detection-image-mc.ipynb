# %%
import os
import glob
import tensorflow as tf
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
# Out:
# 2025-05-05 01:10:21.890947: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746407422.151814      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746407422.232029      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def load_and_split_image_data(
    data_dir: str,
    test_size: float = 0.1,
    val_size: float = 0.2,
    batch_size: int = 32,
    img_size: tuple = (120, 160),
    random_state: int = 42
):
    """
    Load images from class-named subfolders, exclude 'Sample...' folder, preprocess, and split.

    Returns tf.data.Dataset objects for image-only data.
    """

    # find class directories
    class_dirs = [d for d in os.listdir(data_dir)
                  if os.path.isdir(os.path.join(data_dir, d))
                  and not d.startswith("Sample")]
    label_map = {name: idx for idx, name in enumerate(sorted(class_dirs))}

    paths, labels = [], []
    for cls in class_dirs:
        folder = os.path.join(data_dir, cls)
        imgs = glob.glob(os.path.join(folder, "*.jpg")) + glob.glob(os.path.join(folder, "*.png"))
        paths.extend(imgs)
        labels.extend([label_map[cls]] * len(imgs))
    paths = np.array(paths)
    labels = np.array(labels)

    X_temp, X_test, y_temp, y_test = train_test_split(
        paths, labels, test_size=test_size, stratify=labels, random_state=random_state
    )
    val_frac = val_size / (1 - test_size)
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=val_frac, stratify=y_temp, random_state=random_state
    )

    def process_image(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_png(img, channels=3)
        img = tf.image.resize(img, img_size)
        img = tf.cast(img, tf.float32) / 255.0
        return img, label

    def make_ds(paths, labels, shuffle=False):
        ds = tf.data.Dataset.from_tensor_slices((paths, labels))
        ds = ds.map(process_image, num_parallel_calls=tf.data.AUTOTUNE)
        if shuffle:
            ds = ds.shuffle(buffer_size=len(paths), seed=random_state)
        return ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    train_ds = make_ds(X_train, y_train, shuffle=True)
    val_ds   = make_ds(X_val,   y_val,   shuffle=False)
    test_ds  = make_ds(X_test,  y_test,  shuffle=False)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = load_and_split_image_data("../dataset/Thermal Camera Images")
# Out:
# 2025-05-05 01:10:40.474537: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
class MCDropout(tf.keras.layers.Dropout):
    """
    Dropout that is active both at train *and* inference time,
    so we can sample N stochastic forward passes.
    """
    def call(self, inputs, training=None):
        # Force dropout even in inference
        return super().call(inputs, training=True)
    

class MCSpatialDropout2D(tf.keras.layers.SpatialDropout2D):
    """
    Dropout that is active both at train *and* inference time,
    so we can sample N stochastic forward passes.
    """
    def call(self, inputs, training=None):
        # Force dropout even in inference 
        return super().call(inputs, training=True)

# %%
def build_image_model(
    img_shape=(120,160,3),
    conv_filters=(32, 64 , 128),
    layer_dropout = 0.5,
    dense_units=64,
    output_units=4,
    lr=1e-4
):
    """
    Image-only CNN classifier.
    """
    inp = tf.keras.Input(shape=img_shape, name="image_input")
    x = tf.keras.layers.Conv2D(conv_filters[0], 3, activation="relu", padding="same", use_bias=False)(inp)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D()(x)
    x = tf.keras.layers.Conv2D(conv_filters[1], 3, activation="relu", padding="same",use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D()(x)
    x = tf.keras.layers.Conv2D(conv_filters[2], 3, activation="relu", padding="same",use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = MCSpatialDropout2D(0.2)(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(dense_units, activation="relu")(x)
    x = MCDropout(layer_dropout)(x)
    out = tf.keras.layers.Dense(output_units, activation="softmax", name="output")(x)

    model = tf.keras.Model(inp, out, name="image_only")
    model.compile(
        optimizer=tf.keras.optimizers.Adam(lr),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %%
def predict_mc(model, dataset, T=50):
    all_preds = []
    all_labels = []
    for sens_batch, lbl_batch in dataset:
        preds_t = [model(sens_batch).numpy() for _ in range(T)]
        preds_t = np.stack(preds_t, axis=0)  # (T, batch, classes)
        mean_preds = preds_t.mean(axis=0)    # (batch, classes)
        all_preds.append(mean_preds)
        all_labels.append(lbl_batch.numpy())
    all_preds = np.concatenate(all_preds, axis=0)
    all_labels = np.concatenate(all_labels, axis=0)
    y_pred = np.argmax(all_preds, axis=1)
    return np.mean(y_pred == all_labels)

# %%
model = build_image_model()
ckpt_path = "best_image_dropout.keras"
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
        ckpt_path,
        monitor="val_accuracy",
        mode="max",
        save_best_only=True,
        verbose=0
    )
model.fit(train_ds, validation_data=val_ds, epochs=100 , callbacks=[checkpoint_cb])
best_model = tf.keras.models.load_model(
        ckpt_path,
        custom_objects={"MCSpatialDropout2D": MCSpatialDropout2D, "MCDropout": MCDropout}
    )
acc = predict_mc(best_model, test_ds, T=50)
print("testing accuracy is ",acc)
# Out:
# Epoch 1/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.5044 - loss: 1.1376 - val_accuracy: 0.2438 - val_loss: 1.6429
# Epoch 2/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 179s 1s/step - accuracy: 0.6810 - loss: 0.7822 - val_accuracy: 0.2859 - val_loss: 2.3929
# Epoch 3/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.7031 - loss: 0.6939 - val_accuracy: 0.3492 - val_loss: 2.1327
# Epoch 4/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 197s 1s/step - accuracy: 0.7477 - loss: 0.6227 - val_accuracy: 0.5570 - val_loss: 1.2871
# Epoch 5/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.7584 - loss: 0.6187 - val_accuracy: 0.6805 - val_loss: 0.8169
# Epoch 6/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.7705 - loss: 0.5750 - val_accuracy: 0.7945 - val_loss: 0.5263
# Epoch 7/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 205s 1s/step - accuracy: 0.7939 - loss: 0.5274 - val_accuracy: 0.7961 - val_loss: 0.5082
# Epoch 8/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.8020 - loss: 0.5062 - val_accuracy: 0.7766 - val_loss: 0.5360
# Epoch 9/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 206s 1s/step - accuracy: 0.8076 - loss: 0.4792 - val_accuracy: 0.7719 - val_loss: 0.5248
# Epoch 10/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 205s 1s/step - accuracy: 0.8086 - loss: 0.4808 - val_accuracy: 0.7961 - val_loss: 0.4753
# Epoch 11/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 180s 1s/step - accuracy: 0.8245 - loss: 0.4501 - val_accuracy: 0.8469 - val_loss: 0.4238
# Epoch 12/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.8439 - loss: 0.4187 - val_accuracy: 0.8258 - val_loss: 0.4322
# Epoch 13/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - accuracy: 0.8458 - loss: 0.4136 - val_accuracy: 0.8336 - val_loss: 0.4403
# Epoch 14/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.8329 - loss: 0.4071 - val_accuracy: 0.8359 - val_loss: 0.4203
# Epoch 15/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.8463 - loss: 0.3967 - val_accuracy: 0.8336 - val_loss: 0.4464
# Epoch 16/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.8453 - loss: 0.3954 - val_accuracy: 0.8258 - val_loss: 0.4590
# Epoch 17/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.8507 - loss: 0.3826 - val_accuracy: 0.8281 - val_loss: 0.4323
# Epoch 18/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.8587 - loss: 0.3661 - val_accuracy: 0.8547 - val_loss: 0.4123
# Epoch 19/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 185s 1s/step - accuracy: 0.8607 - loss: 0.3650 - val_accuracy: 0.8570 - val_loss: 0.3656
# Epoch 20/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.8672 - loss: 0.3674 - val_accuracy: 0.8383 - val_loss: 0.4194
# Epoch 21/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - accuracy: 0.8697 - loss: 0.3646 - val_accuracy: 0.8578 - val_loss: 0.3990
# Epoch 22/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - accuracy: 0.8672 - loss: 0.3558 - val_accuracy: 0.8656 - val_loss: 0.3591
# Epoch 23/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.8628 - loss: 0.3618 - val_accuracy: 0.8516 - val_loss: 0.3822
# Epoch 24/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.8662 - loss: 0.3355 - val_accuracy: 0.8727 - val_loss: 0.3424
# Epoch 25/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.8708 - loss: 0.3287 - val_accuracy: 0.8633 - val_loss: 0.3727
# Epoch 26/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.8789 - loss: 0.3291 - val_accuracy: 0.8609 - val_loss: 0.4037
# Epoch 27/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.8626 - loss: 0.3499 - val_accuracy: 0.8594 - val_loss: 0.3508
# Epoch 28/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.8880 - loss: 0.3000 - val_accuracy: 0.8781 - val_loss: 0.3434
# Epoch 29/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.8797 - loss: 0.3221 - val_accuracy: 0.8750 - val_loss: 0.3270
# Epoch 30/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 179s 1s/step - accuracy: 0.8881 - loss: 0.2919 - val_accuracy: 0.8766 - val_loss: 0.3338
# Epoch 31/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.8763 - loss: 0.3152 - val_accuracy: 0.8789 - val_loss: 0.3217
# Epoch 32/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.8873 - loss: 0.2956 - val_accuracy: 0.8805 - val_loss: 0.3072
# Epoch 33/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 180s 1s/step - accuracy: 0.8895 - loss: 0.2781 - val_accuracy: 0.8687 - val_loss: 0.3498
# Epoch 34/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.8964 - loss: 0.2716 - val_accuracy: 0.8820 - val_loss: 0.3324
# Epoch 35/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 179s 1s/step - accuracy: 0.8892 - loss: 0.2750 - val_accuracy: 0.8938 - val_loss: 0.2942
# Epoch 36/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.8880 - loss: 0.2903 - val_accuracy: 0.8672 - val_loss: 0.3557
# Epoch 37/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.8910 - loss: 0.2810 - val_accuracy: 0.8875 - val_loss: 0.2830
# Epoch 38/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.9075 - loss: 0.2711 - val_accuracy: 0.8945 - val_loss: 0.2852
# Epoch 39/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.8984 - loss: 0.2628 - val_accuracy: 0.8953 - val_loss: 0.2871
# Epoch 40/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.8971 - loss: 0.2779 - val_accuracy: 0.8625 - val_loss: 0.3778
# Epoch 41/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.8993 - loss: 0.2564 - val_accuracy: 0.9000 - val_loss: 0.2680
# Epoch 42/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.9124 - loss: 0.2397 - val_accuracy: 0.8945 - val_loss: 0.2996
# Epoch 43/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.9019 - loss: 0.2464 - val_accuracy: 0.8578 - val_loss: 0.4001
# Epoch 44/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.8984 - loss: 0.2682 - val_accuracy: 0.8977 - val_loss: 0.2702
# Epoch 45/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 205s 1s/step - accuracy: 0.9083 - loss: 0.2366 - val_accuracy: 0.9023 - val_loss: 0.2792
# Epoch 46/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.9063 - loss: 0.2469 - val_accuracy: 0.9133 - val_loss: 0.2517
# Epoch 47/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.9134 - loss: 0.2407 - val_accuracy: 0.9258 - val_loss: 0.2414
# Epoch 48/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.9258 - loss: 0.2192 - val_accuracy: 0.9133 - val_loss: 0.2697
# Epoch 49/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.9053 - loss: 0.2630 - val_accuracy: 0.9070 - val_loss: 0.2542
# Epoch 50/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.9207 - loss: 0.2150 - val_accuracy: 0.9109 - val_loss: 0.2583
# Epoch 51/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 185s 1s/step - accuracy: 0.9276 - loss: 0.2138 - val_accuracy: 0.8914 - val_loss: 0.2892
# Epoch 52/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.9178 - loss: 0.2216 - val_accuracy: 0.9203 - val_loss: 0.2409
# Epoch 53/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - accuracy: 0.9221 - loss: 0.2104 - val_accuracy: 0.9156 - val_loss: 0.2317
# Epoch 54/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.9198 - loss: 0.2099 - val_accuracy: 0.8977 - val_loss: 0.2710
# Epoch 55/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.9195 - loss: 0.2132 - val_accuracy: 0.9109 - val_loss: 0.2327
# Epoch 56/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.9229 - loss: 0.2132 - val_accuracy: 0.9234 - val_loss: 0.2209
# Epoch 57/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.9217 - loss: 0.2071 - val_accuracy: 0.9109 - val_loss: 0.2382
# Epoch 58/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.9153 - loss: 0.2168 - val_accuracy: 0.9258 - val_loss: 0.2123
# Epoch 59/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 180s 1s/step - accuracy: 0.9212 - loss: 0.2121 - val_accuracy: 0.9055 - val_loss: 0.2538
# Epoch 60/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.9334 - loss: 0.1937 - val_accuracy: 0.9031 - val_loss: 0.2529
# Epoch 61/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.9341 - loss: 0.1844 - val_accuracy: 0.9297 - val_loss: 0.2198
# Epoch 62/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.9274 - loss: 0.1993 - val_accuracy: 0.9187 - val_loss: 0.2252
# Epoch 63/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.9238 - loss: 0.1938 - val_accuracy: 0.9148 - val_loss: 0.2379
# Epoch 64/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.9175 - loss: 0.2198 - val_accuracy: 0.9180 - val_loss: 0.2504
# Epoch 65/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.9289 - loss: 0.1917 - val_accuracy: 0.9258 - val_loss: 0.2100
# Epoch 66/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 199s 1s/step - accuracy: 0.9371 - loss: 0.1841 - val_accuracy: 0.9070 - val_loss: 0.2647
# Epoch 67/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.9225 - loss: 0.1927 - val_accuracy: 0.9141 - val_loss: 0.2580
# Epoch 68/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - accuracy: 0.9375 - loss: 0.1756 - val_accuracy: 0.9227 - val_loss: 0.2269
# Epoch 69/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.9384 - loss: 0.1761 - val_accuracy: 0.9164 - val_loss: 0.2339
# Epoch 70/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.9382 - loss: 0.1785 - val_accuracy: 0.9266 - val_loss: 0.2007
# Epoch 71/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - accuracy: 0.9439 - loss: 0.1688 - val_accuracy: 0.9250 - val_loss: 0.1946
# Epoch 72/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.9405 - loss: 0.1628 - val_accuracy: 0.9266 - val_loss: 0.2058
# Epoch 73/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 180s 1s/step - accuracy: 0.9438 - loss: 0.1624 - val_accuracy: 0.9266 - val_loss: 0.2073
# Epoch 74/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.9365 - loss: 0.1790 - val_accuracy: 0.9281 - val_loss: 0.2031
# Epoch 75/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.9386 - loss: 0.1678 - val_accuracy: 0.9320 - val_loss: 0.2018
# Epoch 76/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 180s 1s/step - accuracy: 0.9421 - loss: 0.1722 - val_accuracy: 0.9133 - val_loss: 0.2389
# Epoch 77/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.9391 - loss: 0.1618 - val_accuracy: 0.9328 - val_loss: 0.1848
# Epoch 78/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 185s 1s/step - accuracy: 0.9446 - loss: 0.1603 - val_accuracy: 0.9273 - val_loss: 0.2210
# Epoch 79/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 207s 1s/step - accuracy: 0.9510 - loss: 0.1444 - val_accuracy: 0.9305 - val_loss: 0.2079
# Epoch 80/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.9457 - loss: 0.1506 - val_accuracy: 0.9234 - val_loss: 0.1943
# Epoch 81/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.9417 - loss: 0.1651 - val_accuracy: 0.9133 - val_loss: 0.2285
# Epoch 82/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.9413 - loss: 0.1623 - val_accuracy: 0.9250 - val_loss: 0.1869
# Epoch 83/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 193s 1s/step - accuracy: 0.9500 - loss: 0.1525 - val_accuracy: 0.9305 - val_loss: 0.1838
# Epoch 84/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.9479 - loss: 0.1428 - val_accuracy: 0.9180 - val_loss: 0.2031
# Epoch 85/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.9430 - loss: 0.1479 - val_accuracy: 0.9391 - val_loss: 0.1689
# Epoch 86/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.9373 - loss: 0.1613 - val_accuracy: 0.9305 - val_loss: 0.1817
# Epoch 87/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 194s 1s/step - accuracy: 0.9453 - loss: 0.1514 - val_accuracy: 0.9266 - val_loss: 0.1991
# Epoch 88/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.9545 - loss: 0.1407 - val_accuracy: 0.9328 - val_loss: 0.1874
# Epoch 89/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 194s 1s/step - accuracy: 0.9457 - loss: 0.1538 - val_accuracy: 0.9438 - val_loss: 0.1753
# Epoch 90/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 193s 1s/step - accuracy: 0.9461 - loss: 0.1464 - val_accuracy: 0.9297 - val_loss: 0.1826
# Epoch 91/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.9471 - loss: 0.1344 - val_accuracy: 0.9477 - val_loss: 0.1655
# Epoch 92/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.9512 - loss: 0.1277 - val_accuracy: 0.9227 - val_loss: 0.2146
# Epoch 93/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 194s 1s/step - accuracy: 0.9541 - loss: 0.1278 - val_accuracy: 0.9414 - val_loss: 0.1664
# Epoch 94/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.9487 - loss: 0.1418 - val_accuracy: 0.9406 - val_loss: 0.1850
# Epoch 95/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - accuracy: 0.9467 - loss: 0.1410 - val_accuracy: 0.9383 - val_loss: 0.1705
# Epoch 96/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.9465 - loss: 0.1458 - val_accuracy: 0.9281 - val_loss: 0.1917
# Epoch 97/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.9575 - loss: 0.1247 - val_accuracy: 0.9422 - val_loss: 0.1788
# Epoch 98/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.9512 - loss: 0.1266 - val_accuracy: 0.9336 - val_loss: 0.1887
# Epoch 99/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.9463 - loss: 0.1356 - val_accuracy: 0.9344 - val_loss: 0.1967
# Epoch 100/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.9549 - loss: 0.1286 - val_accuracy: 0.9375 - val_loss: 0.1910
# testing accuracy is  0.940625

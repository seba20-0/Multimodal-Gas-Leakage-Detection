# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# Out:
# 2025-05-05 00:44:29.066281: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746405869.278291      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746405869.342355      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def load_and_split_multimodal_data(
    sensor_csv_path: str,
    image_data_dir: str,
    test_size: float = 0.1,
    val_size: float = 0.2,
    batch_size: int = 32,
    img_size: tuple = (120, 160),
    random_state: int = 42
):
    """
    Load and split both sensor CSV and image folders into multimodal tf.data.Datasets.

    Args:
        sensor_csv_path: Path to the gas sensor CSV.
        image_data_dir: Base directory of image class subfolders.
        test_size: Fraction of data reserved for testing.
        val_size: Fraction of remaining data reserved for validation.
        batch_size: Batch size for tf.data pipelines.
        img_size: Size to resize images to (height, width).
        random_state: Seed for reproducibility.

    Returns:
        train_ds, val_ds, test_ds: tf.data.Dataset yielding ((sensor, image), label).
    """
    # 1) Load sensor CSV
    sdf = pd.read_csv(sensor_csv_path)
    sdf = sdf.drop(columns=["Serial Number"], errors='ignore')
    sdf['Gas'] = sdf['Gas'].astype('category').cat.codes

    # Build image filename column
    sdf['Image_File'] = sdf['Corresponding Image Name'].astype(str) + ".png"

    # Extract sensor features and labels
    sensor_cols = [c for c in sdf.columns if c not in ['Gas', 'Corresponding Image Name', 'Image_File']]
    sensors = sdf[sensor_cols].values.astype('float32')
    labels = sdf['Gas'].values.astype('int32')

    # Normalize sensors
    scaler = StandardScaler().fit(sensors)
    sensors = scaler.transform(sensors)

    # Map image names to full paths
    base = image_data_dir
    def find_path(fname):
        for cls in os.listdir(base):
            p = os.path.join(base, cls, fname)
            if os.path.exists(p):
                return p
        return None

    paths = np.array(sdf['Image_File'].map(find_path))
    valid = ~pd.isna(paths)

    sensors = sensors[valid]
    paths   = paths[valid]
    labels  = labels[valid]

    # Split multimodal arrays
    X_temp, X_test, S_temp, S_test, y_temp, y_test = train_test_split(
        paths, sensors, labels,
        test_size=test_size, stratify=labels, random_state=random_state
    )
    val_frac = val_size / (1 - test_size)
    X_train, X_val, S_train, S_val, y_train, y_val = train_test_split(
        X_temp, S_temp, y_temp,
        test_size=val_frac, stratify=y_temp, random_state=random_state
    )

    # Define loader
    def loader(path, sens, lab):
        img = tf.io.read_file(path)
        img = tf.image.decode_png(img, channels=3)
        img = tf.image.resize(img, img_size)
        img = tf.cast(img, tf.float32) / 255.0
        sens = tf.cast(sens, tf.float32)
        return (sens, img), lab

    # Build tf.data datasets
    def make_ds(paths, sensors, labels, shuffle=False):
        ds = tf.data.Dataset.from_tensor_slices((paths, sensors, labels))
        ds = ds.map(loader, num_parallel_calls=tf.data.AUTOTUNE)
        if shuffle:
            ds = ds.shuffle(buffer_size=len(labels), seed=random_state)
        return ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    train_ds = make_ds(X_train, S_train, y_train, shuffle=True)
    val_ds   = make_ds(X_val,   S_val,   y_val,   shuffle=False)
    test_ds  = make_ds(X_test,  S_test,  y_test,  shuffle=False)

    return train_ds, val_ds, test_ds

train_ds, val_ds, test_ds = load_and_split_multimodal_data(
    sensor_csv_path=  "../dataset/Gas Sensors Measurements/Gas_Sensors_Measurements.csv",
    image_data_dir="../dataset/Thermal Camera Images")
# Out:
# I0000 00:00:1746405901.142246      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1746405901.142913      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
class RandomSensorDropout(tf.keras.layers.Layer):
    """
    Layer that randomly zeros individual sensor channels with a given rate during training.
    Supports proper serialization.
    """
    def __init__(self, rate=0.3, **kwargs):
        super().__init__(**kwargs)
        self.rate = rate

    def call(self, inputs, training=False):
        if training and self.rate > 0.0:
            mask = tf.cast(tf.random.uniform(tf.shape(inputs)) > self.rate, inputs.dtype)
            return inputs * mask
        return inputs

    def get_config(self):
        config = super().get_config()
        config.update({"rate": self.rate})
        return config
    

# --------------- Monte Carlo Dropout Layers ---------------------    
class MCDropout(tf.keras.layers.Dropout):
    """
    Dropout that is active both at train *and* inference time,
    so we can sample N stochastic forward passes.
    """
    def call(self, inputs, training=None):
        # Force dropout even in inference
        return super().call(inputs, training=True)
    

class MCSpatialDropout2D(tf.keras.layers.SpatialDropout2D):
    """
    Dropout that is active both at train *and* inference time,
    so we can sample N stochastic forward passes.
    """
    def call(self, inputs, training=None):
        # Force dropout even in inference
        return super().call(inputs, training=True)

# %%
def build_multimodal_model(
    img_shape=(120, 160, 3),
    input_dim=7,
    sensor_dropout_rate=0.3,
    layer_dropout=0.5,
    sensor_units=32,
    img_dense=64,
    fusion_dense=64,
    output_units=4,
    lr=1e-4
):
    """
    Intermediate fusion of sensor and image branches.
    Enhanced image branch with deeper layers and normalization.
    """
    # Sensor input
    inp = tf.keras.Input(shape=(input_dim,), name="sensor_input")
    x = RandomSensorDropout(sensor_dropout_rate, name="sensor_dropout")(inp)
    x = tf.keras.layers.Dense(64, activation="relu")(x)
    x = MCDropout(0.5)(x)
    s = tf.keras.layers.Dense(32, activation="relu")(x)

    # Image input
    i_in = tf.keras.Input(shape=img_shape, name="image_input")
    x = tf.keras.layers.Conv2D(32, 3, padding="same", activation="relu" ,use_bias=False)(i_in)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D()(x)

    x = tf.keras.layers.Conv2D(64, 3, padding="same", activation="relu", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D()(x)

    x = tf.keras.layers.Conv2D(128, 3, padding="same", activation="relu", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = MCSpatialDropout2D(0.2)(x)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(img_dense, activation="relu")(x)
    x = MCDropout(layer_dropout)(x)

    # Fusion
    fused = tf.keras.layers.Concatenate()([s, x])
    y = tf.keras.layers.Dense(fusion_dense, activation="relu")(fused)
    y = MCDropout(layer_dropout)(y)
    out = tf.keras.layers.Dense(output_units, activation="softmax", name="output")(y)

    # Model compile
    model = tf.keras.Model([inp, i_in], out, name="multimodal")
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %%
model = build_multimodal_model()
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_mc_sensor_model.keras', monitor='val_accuracy',
    save_best_only=True, mode='max' 
)
model.fit(train_ds , validation_data = val_ds , epochs = 100 , batch_size = 32 , callbacks = [checkpoint])
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746405931.115882      61 service.cc:148] XLA service 0x7925ac089040 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746405931.117109      61 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746405931.117132      61 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746405931.612650      61 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   5/140 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.2861 - loss: 1.5832
# I0000 00:00:1746405937.200346      61 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 49s 109ms/step - accuracy: 0.3829 - loss: 1.3206 - val_accuracy: 0.2875 - val_loss: 1.4052
# Epoch 2/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 31s 66ms/step - accuracy: 0.5830 - loss: 0.9785 - val_accuracy: 0.3555 - val_loss: 1.4751
# Epoch 3/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 32s 64ms/step - accuracy: 0.6500 - loss: 0.8525 - val_accuracy: 0.4305 - val_loss: 1.2688
# Epoch 4/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 36s 94ms/step - accuracy: 0.7061 - loss: 0.7363 - val_accuracy: 0.6711 - val_loss: 0.7902
# Epoch 5/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 31s 94ms/step - accuracy: 0.7540 - loss: 0.6297 - val_accuracy: 0.7875 - val_loss: 0.5261
# Epoch 6/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 28s 57ms/step - accuracy: 0.7889 - loss: 0.5319 - val_accuracy: 0.8195 - val_loss: 0.4513
# Epoch 7/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 57ms/step - accuracy: 0.8042 - loss: 0.4800 - val_accuracy: 0.8414 - val_loss: 0.3801
# Epoch 8/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 56ms/step - accuracy: 0.8203 - loss: 0.4483 - val_accuracy: 0.8297 - val_loss: 0.4043
# Epoch 9/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.8254 - loss: 0.4223 - val_accuracy: 0.8211 - val_loss: 0.3698
# Epoch 10/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.8285 - loss: 0.3993 - val_accuracy: 0.8555 - val_loss: 0.3330
# Epoch 11/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 28s 57ms/step - accuracy: 0.8346 - loss: 0.3670 - val_accuracy: 0.8648 - val_loss: 0.3082
# Epoch 12/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 56ms/step - accuracy: 0.8482 - loss: 0.3575 - val_accuracy: 0.8609 - val_loss: 0.3065
# Epoch 13/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 27s 68ms/step - accuracy: 0.8516 - loss: 0.3378 - val_accuracy: 0.8719 - val_loss: 0.3002
# Epoch 14/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 28s 57ms/step - accuracy: 0.8545 - loss: 0.3362 - val_accuracy: 0.8742 - val_loss: 0.2692
# Epoch 15/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.8702 - loss: 0.3097 - val_accuracy: 0.8781 - val_loss: 0.2711
# Epoch 16/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.8557 - loss: 0.3232 - val_accuracy: 0.8719 - val_loss: 0.2779
# Epoch 17/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.8735 - loss: 0.2977 - val_accuracy: 0.8875 - val_loss: 0.2512
# Epoch 18/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 59ms/step - accuracy: 0.8809 - loss: 0.2826 - val_accuracy: 0.8922 - val_loss: 0.2439
# Epoch 19/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 61ms/step - accuracy: 0.8870 - loss: 0.2696 - val_accuracy: 0.8797 - val_loss: 0.2688
# Epoch 20/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 27s 57ms/step - accuracy: 0.8758 - loss: 0.2820 - val_accuracy: 0.9023 - val_loss: 0.2349
# Epoch 21/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.8841 - loss: 0.2696 - val_accuracy: 0.8938 - val_loss: 0.2632
# Epoch 22/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.8822 - loss: 0.2711 - val_accuracy: 0.9164 - val_loss: 0.2116
# Epoch 23/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 27s 56ms/step - accuracy: 0.8937 - loss: 0.2568 - val_accuracy: 0.9102 - val_loss: 0.2140
# Epoch 24/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 60ms/step - accuracy: 0.9066 - loss: 0.2361 - val_accuracy: 0.9180 - val_loss: 0.2028
# Epoch 25/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 41s 55ms/step - accuracy: 0.8952 - loss: 0.2514 - val_accuracy: 0.9094 - val_loss: 0.2018
# Epoch 26/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 60ms/step - accuracy: 0.9082 - loss: 0.2327 - val_accuracy: 0.9016 - val_loss: 0.2290
# Epoch 27/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 57ms/step - accuracy: 0.9134 - loss: 0.2249 - val_accuracy: 0.9273 - val_loss: 0.1840
# Epoch 28/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9072 - loss: 0.2367 - val_accuracy: 0.9336 - val_loss: 0.1764
# Epoch 29/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.9135 - loss: 0.2025 - val_accuracy: 0.9328 - val_loss: 0.1877
# Epoch 30/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9195 - loss: 0.2099 - val_accuracy: 0.9258 - val_loss: 0.1790
# Epoch 31/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 28s 59ms/step - accuracy: 0.9158 - loss: 0.2199 - val_accuracy: 0.9352 - val_loss: 0.1612
# Epoch 32/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 57ms/step - accuracy: 0.9181 - loss: 0.2079 - val_accuracy: 0.9242 - val_loss: 0.1837
# Epoch 33/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9112 - loss: 0.2166 - val_accuracy: 0.9367 - val_loss: 0.1705
# Epoch 34/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9226 - loss: 0.1918 - val_accuracy: 0.9250 - val_loss: 0.1727
# Epoch 35/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9338 - loss: 0.1726 - val_accuracy: 0.9414 - val_loss: 0.1705
# Epoch 36/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 31s 95ms/step - accuracy: 0.9250 - loss: 0.1928 - val_accuracy: 0.9430 - val_loss: 0.1512
# Epoch 37/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 31s 95ms/step - accuracy: 0.9260 - loss: 0.1900 - val_accuracy: 0.9461 - val_loss: 0.1421
# Epoch 38/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 60ms/step - accuracy: 0.9376 - loss: 0.1746 - val_accuracy: 0.9453 - val_loss: 0.1590
# Epoch 39/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 57ms/step - accuracy: 0.9289 - loss: 0.1854 - val_accuracy: 0.9344 - val_loss: 0.1499
# Epoch 40/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 42s 61ms/step - accuracy: 0.9376 - loss: 0.1655 - val_accuracy: 0.9297 - val_loss: 0.1608
# Epoch 41/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 58ms/step - accuracy: 0.9332 - loss: 0.1712 - val_accuracy: 0.9477 - val_loss: 0.1359
# Epoch 42/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9373 - loss: 0.1660 - val_accuracy: 0.9484 - val_loss: 0.1348
# Epoch 43/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9382 - loss: 0.1709 - val_accuracy: 0.9383 - val_loss: 0.1513
# Epoch 44/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9423 - loss: 0.1583 - val_accuracy: 0.9508 - val_loss: 0.1309
# Epoch 45/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 60ms/step - accuracy: 0.9365 - loss: 0.1605 - val_accuracy: 0.9547 - val_loss: 0.1358
# Epoch 46/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9462 - loss: 0.1446 - val_accuracy: 0.9484 - val_loss: 0.1369
# Epoch 47/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9406 - loss: 0.1584 - val_accuracy: 0.9523 - val_loss: 0.1259
# Epoch 48/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9387 - loss: 0.1720 - val_accuracy: 0.9500 - val_loss: 0.1382
# Epoch 49/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9516 - loss: 0.1362 - val_accuracy: 0.9477 - val_loss: 0.1429
# Epoch 50/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 28s 67ms/step - accuracy: 0.9440 - loss: 0.1525 - val_accuracy: 0.9375 - val_loss: 0.1440
# Epoch 51/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 29s 65ms/step - accuracy: 0.9455 - loss: 0.1519 - val_accuracy: 0.9547 - val_loss: 0.1192
# Epoch 52/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 29s 61ms/step - accuracy: 0.9425 - loss: 0.1518 - val_accuracy: 0.9500 - val_loss: 0.1254
# Epoch 53/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 29s 62ms/step - accuracy: 0.9517 - loss: 0.1344 - val_accuracy: 0.9516 - val_loss: 0.1422
# Epoch 54/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 30s 62ms/step - accuracy: 0.9517 - loss: 0.1429 - val_accuracy: 0.9453 - val_loss: 0.1346
# Epoch 55/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 31s 68ms/step - accuracy: 0.9495 - loss: 0.1442 - val_accuracy: 0.9508 - val_loss: 0.1388
# Epoch 56/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 29s 57ms/step - accuracy: 0.9516 - loss: 0.1362 - val_accuracy: 0.9539 - val_loss: 0.1153
# Epoch 57/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 37s 56ms/step - accuracy: 0.9540 - loss: 0.1333 - val_accuracy: 0.9578 - val_loss: 0.1218
# Epoch 58/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 58ms/step - accuracy: 0.9486 - loss: 0.1473 - val_accuracy: 0.9648 - val_loss: 0.1042
# Epoch 59/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 56ms/step - accuracy: 0.9627 - loss: 0.1159 - val_accuracy: 0.9539 - val_loss: 0.1300
# Epoch 60/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 56ms/step - accuracy: 0.9535 - loss: 0.1217 - val_accuracy: 0.9570 - val_loss: 0.1152
# Epoch 61/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 60ms/step - accuracy: 0.9535 - loss: 0.1396 - val_accuracy: 0.9563 - val_loss: 0.1202
# Epoch 62/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 56ms/step - accuracy: 0.9565 - loss: 0.1207 - val_accuracy: 0.9578 - val_loss: 0.1081
# Epoch 63/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.9578 - loss: 0.1177 - val_accuracy: 0.9609 - val_loss: 0.1163
# Epoch 64/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 56ms/step - accuracy: 0.9533 - loss: 0.1378 - val_accuracy: 0.9586 - val_loss: 0.1212
# Epoch 65/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 56ms/step - accuracy: 0.9545 - loss: 0.1249 - val_accuracy: 0.9602 - val_loss: 0.1004
# Epoch 66/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 58ms/step - accuracy: 0.9583 - loss: 0.1137 - val_accuracy: 0.9602 - val_loss: 0.1061
# Epoch 67/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 56ms/step - accuracy: 0.9563 - loss: 0.1207 - val_accuracy: 0.9570 - val_loss: 0.1062
# Epoch 68/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.9621 - loss: 0.1137 - val_accuracy: 0.9617 - val_loss: 0.0987
# Epoch 69/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.9564 - loss: 0.1239 - val_accuracy: 0.9523 - val_loss: 0.1235
# Epoch 70/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 57ms/step - accuracy: 0.9607 - loss: 0.1136 - val_accuracy: 0.9531 - val_loss: 0.1117
# Epoch 71/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 57ms/step - accuracy: 0.9636 - loss: 0.1082 - val_accuracy: 0.9609 - val_loss: 0.1077
# Epoch 72/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9615 - loss: 0.1058 - val_accuracy: 0.9656 - val_loss: 0.0971
# Epoch 73/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.9580 - loss: 0.1128 - val_accuracy: 0.9656 - val_loss: 0.1087
# Epoch 74/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.9628 - loss: 0.1014 - val_accuracy: 0.9602 - val_loss: 0.1161
# Epoch 75/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 60ms/step - accuracy: 0.9583 - loss: 0.1126 - val_accuracy: 0.9641 - val_loss: 0.1108
# Epoch 76/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 57ms/step - accuracy: 0.9677 - loss: 0.0972 - val_accuracy: 0.9555 - val_loss: 0.1422
# Epoch 77/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.9690 - loss: 0.0933 - val_accuracy: 0.9664 - val_loss: 0.0943
# Epoch 78/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 58ms/step - accuracy: 0.9614 - loss: 0.1041 - val_accuracy: 0.9688 - val_loss: 0.1004
# Epoch 79/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 58ms/step - accuracy: 0.9683 - loss: 0.0973 - val_accuracy: 0.9625 - val_loss: 0.1065
# Epoch 80/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 27s 60ms/step - accuracy: 0.9651 - loss: 0.1006 - val_accuracy: 0.9617 - val_loss: 0.0934
# Epoch 81/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 56ms/step - accuracy: 0.9614 - loss: 0.1088 - val_accuracy: 0.9633 - val_loss: 0.0947
# Epoch 82/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.9681 - loss: 0.1053 - val_accuracy: 0.9656 - val_loss: 0.1092
# Epoch 83/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.9653 - loss: 0.0997 - val_accuracy: 0.9680 - val_loss: 0.0982
# Epoch 84/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.9628 - loss: 0.1196 - val_accuracy: 0.9602 - val_loss: 0.1037
# Epoch 85/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 60ms/step - accuracy: 0.9722 - loss: 0.0908 - val_accuracy: 0.9633 - val_loss: 0.0932
# Epoch 86/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 57ms/step - accuracy: 0.9710 - loss: 0.0864 - val_accuracy: 0.9633 - val_loss: 0.0939
# Epoch 87/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 61ms/step - accuracy: 0.9653 - loss: 0.1061 - val_accuracy: 0.9523 - val_loss: 0.1038
# Epoch 88/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9697 - loss: 0.0880 - val_accuracy: 0.9547 - val_loss: 0.1141
# Epoch 89/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9647 - loss: 0.1002 - val_accuracy: 0.9531 - val_loss: 0.1274
# Epoch 90/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 60ms/step - accuracy: 0.9697 - loss: 0.0859 - val_accuracy: 0.9680 - val_loss: 0.0937
# Epoch 91/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 56ms/step - accuracy: 0.9644 - loss: 0.0882 - val_accuracy: 0.9734 - val_loss: 0.0928
# Epoch 92/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.9629 - loss: 0.1054 - val_accuracy: 0.9711 - val_loss: 0.0931
# Epoch 93/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9681 - loss: 0.0865 - val_accuracy: 0.9633 - val_loss: 0.0990
# Epoch 94/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 56ms/step - accuracy: 0.9753 - loss: 0.0770 - val_accuracy: 0.9688 - val_loss: 0.0875
# Epoch 95/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 30s 94ms/step - accuracy: 0.9724 - loss: 0.0876 - val_accuracy: 0.9727 - val_loss: 0.0779
# Epoch 96/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 30s 94ms/step - accuracy: 0.9684 - loss: 0.0849 - val_accuracy: 0.9641 - val_loss: 0.1007
# Epoch 97/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 25s 56ms/step - accuracy: 0.9694 - loss: 0.0819 - val_accuracy: 0.9586 - val_loss: 0.1153
# Epoch 98/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.9654 - loss: 0.0885 - val_accuracy: 0.9648 - val_loss: 0.0839
# Epoch 99/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.9723 - loss: 0.0908 - val_accuracy: 0.9609 - val_loss: 0.0993
# Epoch 100/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 57ms/step - accuracy: 0.9739 - loss: 0.0790 - val_accuracy: 0.9656 - val_loss: 0.1002

# %%
best_model = tf.keras.models.load_model(
        'best_mc_sensor_model.keras',
        custom_objects={"RandomSensorDropout": RandomSensorDropout, "MCDropout": MCDropout,"MCSpatialDropout2D": MCSpatialDropout2D}
    )
def predict_mc(model, dataset, T=50):
    all_preds = []
    all_labels = []
    for sens_batch, lbl_batch in dataset:
        preds_t = [model(sens_batch).numpy() for _ in range(T)]
        preds_t = np.stack(preds_t, axis=0)  # (T, batch, classes)
        mean_preds = preds_t.mean(axis=0)    # (batch, classes)
        all_preds.append(mean_preds)
        all_labels.append(lbl_batch.numpy())
    all_preds = np.concatenate(all_preds, axis=0)
    all_labels = np.concatenate(all_labels, axis=0)
    y_pred = np.argmax(all_preds, axis=1)
    return np.mean(y_pred == all_labels)
acc = predict_mc(best_model , test_ds)
print("testing accuracy is " ,acc)
# Out:
# testing accuracy is  0.9796875

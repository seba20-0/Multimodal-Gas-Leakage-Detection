# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# Out:
# 2025-05-05 00:51:11.308834: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746406271.535567      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746406271.598312      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def load_and_split_multimodal_data(
    sensor_csv_path: str,
    image_data_dir: str,
    test_size: float = 0.1,
    val_size: float = 0.2,
    batch_size: int = 32,
    img_size: tuple = (120, 160),
    random_state: int = 42
):
    """
    Load and split both sensor CSV and image folders into multimodal tf.data.Datasets.

    Args:
        sensor_csv_path: Path to the gas sensor CSV.
        image_data_dir: Base directory of image class subfolders.
        test_size: Fraction of data reserved for testing.
        val_size: Fraction of remaining data reserved for validation.
        batch_size: Batch size for tf.data pipelines.
        img_size: Size to resize images to (height, width).
        random_state: Seed for reproducibility.

    Returns:
        train_ds, val_ds, test_ds: tf.data.Dataset yielding ((sensor, image), label).
    """
    # 1) Load sensor CSV
    sdf = pd.read_csv(sensor_csv_path)
    sdf = sdf.drop(columns=["Serial Number"], errors='ignore')
    sdf['Gas'] = sdf['Gas'].astype('category').cat.codes

    # Build image filename column
    sdf['Image_File'] = sdf['Corresponding Image Name'].astype(str) + ".png"

    # Extract sensor features and labels
    sensor_cols = [c for c in sdf.columns if c not in ['Gas', 'Corresponding Image Name', 'Image_File']]
    sensors = sdf[sensor_cols].values.astype('float32')
    labels = sdf['Gas'].values.astype('int32')

    # Normalize sensors
    scaler = StandardScaler().fit(sensors)
    sensors = scaler.transform(sensors)

    # Map image names to full paths
    base = image_data_dir
    def find_path(fname):
        for cls in os.listdir(base):
            p = os.path.join(base, cls, fname)
            if os.path.exists(p):
                return p
        return None

    paths = np.array(sdf['Image_File'].map(find_path))
    valid = ~pd.isna(paths)

    sensors = sensors[valid]
    paths   = paths[valid]
    labels  = labels[valid]

    # Split multimodal arrays
    X_temp, X_test, S_temp, S_test, y_temp, y_test = train_test_split(
        paths, sensors, labels,
        test_size=test_size, stratify=labels, random_state=random_state
    )
    val_frac = val_size / (1 - test_size)
    X_train, X_val, S_train, S_val, y_train, y_val = train_test_split(
        X_temp, S_temp, y_temp,
        test_size=val_frac, stratify=y_temp, random_state=random_state
    )

    # Define loader
    def loader(path, sens, lab):
        img = tf.io.read_file(path)
        img = tf.image.decode_png(img, channels=3)
        img = tf.image.resize(img, img_size)
        img = tf.cast(img, tf.float32) / 255.0
        sens = tf.cast(sens, tf.float32)
        return (sens, img), lab

    # Build tf.data datasets
    def make_ds(paths, sensors, labels, shuffle=False):
        ds = tf.data.Dataset.from_tensor_slices((paths, sensors, labels))
        ds = ds.map(loader, num_parallel_calls=tf.data.AUTOTUNE)
        if shuffle:
            ds = ds.shuffle(buffer_size=len(labels), seed=random_state)
        return ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    train_ds = make_ds(X_train, S_train, y_train, shuffle=True)
    val_ds   = make_ds(X_val,   S_val,   y_val,   shuffle=False)
    test_ds  = make_ds(X_test,  S_test,  y_test,  shuffle=False)

    return train_ds, val_ds, test_ds

train_ds, val_ds, test_ds = load_and_split_multimodal_data(
    sensor_csv_path=  "../dataset/Gas Sensors Measurements/Gas_Sensors_Measurements.csv",
    image_data_dir="../dataset/Thermal Camera Images")
# Out:
# 2025-05-05 00:51:41.347343: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
class RandomSensorDropout(tf.keras.layers.Layer):
    """
    Layer that randomly zeros individual sensor channels with a given rate during training.
    Supports proper serialization.
    """
    def __init__(self, rate=0.3, **kwargs):
        super().__init__(**kwargs)
        self.rate = rate

    def call(self, inputs, training=False):
        if training and self.rate > 0.0:
            mask = tf.cast(tf.random.uniform(tf.shape(inputs)) > self.rate, inputs.dtype)
            return inputs * mask
        return inputs

    def get_config(self):
        config = super().get_config()
        config.update({"rate": self.rate})
        return config

# %%
def build_multimodal_model(
    img_shape=(120, 160, 3),
    input_dim=7,
    sensor_dropout_rate=0.3,
    layer_dropout=0.5,
    sensor_units=32,
    img_dense=64,
    fusion_dense=64,
    output_units=4,
    lr=1e-4
):
    """
    Intermediate fusion of sensor and image branches.
    Enhanced image branch with deeper layers and normalization.
    """
    # Sensor input
    inp = tf.keras.Input(shape=(input_dim,), name="sensor_input")
    x = RandomSensorDropout(sensor_dropout_rate, name="sensor_dropout")(inp)
    x = tf.keras.layers.Dense(64, activation="relu")(x)
    x = tf.keras.layers.Dropout(layer_dropout)(x)
    s = tf.keras.layers.Dense(32, activation="relu")(x)

    # Image input
    i_in = tf.keras.Input(shape=img_shape, name="image_input")
    x = tf.keras.layers.Conv2D(32, 3, padding="same", activation="relu" ,use_bias=False)(i_in)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D()(x)

    x = tf.keras.layers.Conv2D(64, 3, padding="same", activation="relu", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D()(x)

    x = tf.keras.layers.Conv2D(128, 3, padding="same", activation="relu", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.SpatialDropout2D(0.2)(x)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(img_dense, activation="relu")(x)
    x = tf.keras.layers.Dropout(layer_dropout)(x)

    # Fusion
    fused = tf.keras.layers.Concatenate()([s, x])
    y = tf.keras.layers.Dense(fusion_dense, activation="relu")(fused)
    y = tf.keras.layers.Dropout(layer_dropout)(y)
    out = tf.keras.layers.Dense(output_units, activation="softmax", name="output")(y)

    # Model compile
    model = tf.keras.Model([inp, i_in], out, name="multimodal")
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %%
model = build_multimodal_model()
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_model.keras', monitor='val_accuracy',
    save_best_only=True, mode='max', verbose=1
)
history = model.fit(train_ds,
                    validation_data=val_ds,
                    epochs=100,
                    batch_size=32, callbacks = [checkpoint])
# Out:
# Epoch 1/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 993ms/step - accuracy: 0.3690 - loss: 1.3576
# Epoch 1: val_accuracy improved from -inf to 0.38672, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 194s 1s/step - accuracy: 0.3695 - loss: 1.3565 - val_accuracy: 0.3867 - val_loss: 1.2851
# Epoch 2/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 966ms/step - accuracy: 0.5841 - loss: 0.9776
# Epoch 2: val_accuracy did not improve from 0.38672
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.5842 - loss: 0.9773 - val_accuracy: 0.3641 - val_loss: 1.2424
# Epoch 3/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 976ms/step - accuracy: 0.6424 - loss: 0.8438
# Epoch 3: val_accuracy improved from 0.38672 to 0.50625, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.6426 - loss: 0.8436 - val_accuracy: 0.5063 - val_loss: 1.0220
# Epoch 4/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 959ms/step - accuracy: 0.7116 - loss: 0.7171
# Epoch 4: val_accuracy improved from 0.50625 to 0.68047, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.7117 - loss: 0.7169 - val_accuracy: 0.6805 - val_loss: 0.6388
# Epoch 5/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 965ms/step - accuracy: 0.7526 - loss: 0.6273
# Epoch 5: val_accuracy improved from 0.68047 to 0.84062, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.7527 - loss: 0.6272 - val_accuracy: 0.8406 - val_loss: 0.4223
# Epoch 6/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 964ms/step - accuracy: 0.7779 - loss: 0.5557
# Epoch 6: val_accuracy improved from 0.84062 to 0.85703, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.7779 - loss: 0.5556 - val_accuracy: 0.8570 - val_loss: 0.3319
# Epoch 7/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 968ms/step - accuracy: 0.7967 - loss: 0.5006
# Epoch 7: val_accuracy improved from 0.85703 to 0.87187, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.7968 - loss: 0.5005 - val_accuracy: 0.8719 - val_loss: 0.2880
# Epoch 8/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 960ms/step - accuracy: 0.8159 - loss: 0.4259
# Epoch 8: val_accuracy improved from 0.87187 to 0.87656, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.8159 - loss: 0.4260 - val_accuracy: 0.8766 - val_loss: 0.2694
# Epoch 9/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 960ms/step - accuracy: 0.8308 - loss: 0.4109
# Epoch 9: val_accuracy improved from 0.87656 to 0.88750, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.8308 - loss: 0.4109 - val_accuracy: 0.8875 - val_loss: 0.2547
# Epoch 10/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 961ms/step - accuracy: 0.8246 - loss: 0.4015
# Epoch 10: val_accuracy did not improve from 0.88750
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.8246 - loss: 0.4014 - val_accuracy: 0.8758 - val_loss: 0.2492
# Epoch 11/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 968ms/step - accuracy: 0.8439 - loss: 0.3867
# Epoch 11: val_accuracy improved from 0.88750 to 0.88828, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.8439 - loss: 0.3866 - val_accuracy: 0.8883 - val_loss: 0.2348
# Epoch 12/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 962ms/step - accuracy: 0.8507 - loss: 0.3508
# Epoch 12: val_accuracy improved from 0.88828 to 0.89609, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.8507 - loss: 0.3508 - val_accuracy: 0.8961 - val_loss: 0.2397
# Epoch 13/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 958ms/step - accuracy: 0.8583 - loss: 0.3364
# Epoch 13: val_accuracy improved from 0.89609 to 0.91406, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.8583 - loss: 0.3364 - val_accuracy: 0.9141 - val_loss: 0.2273
# Epoch 14/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 962ms/step - accuracy: 0.8556 - loss: 0.3361
# Epoch 14: val_accuracy did not improve from 0.91406
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.8556 - loss: 0.3361 - val_accuracy: 0.9055 - val_loss: 0.2089
# Epoch 15/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 961ms/step - accuracy: 0.8690 - loss: 0.3234
# Epoch 15: val_accuracy improved from 0.91406 to 0.91953, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.8690 - loss: 0.3234 - val_accuracy: 0.9195 - val_loss: 0.1971
# Epoch 16/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 953ms/step - accuracy: 0.8717 - loss: 0.3052
# Epoch 16: val_accuracy did not improve from 0.91953
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.8717 - loss: 0.3052 - val_accuracy: 0.9156 - val_loss: 0.1950
# Epoch 17/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 957ms/step - accuracy: 0.8713 - loss: 0.2968
# Epoch 17: val_accuracy did not improve from 0.91953
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.8713 - loss: 0.2967 - val_accuracy: 0.9078 - val_loss: 0.1905
# Epoch 18/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 970ms/step - accuracy: 0.8943 - loss: 0.2722
# Epoch 18: val_accuracy did not improve from 0.91953
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.8943 - loss: 0.2722 - val_accuracy: 0.9094 - val_loss: 0.1894
# Epoch 19/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 975ms/step - accuracy: 0.8828 - loss: 0.2712
# Epoch 19: val_accuracy improved from 0.91953 to 0.92656, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 0.8828 - loss: 0.2712 - val_accuracy: 0.9266 - val_loss: 0.1821
# Epoch 20/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 976ms/step - accuracy: 0.8915 - loss: 0.2642
# Epoch 20: val_accuracy did not improve from 0.92656
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 178s 1s/step - accuracy: 0.8915 - loss: 0.2641 - val_accuracy: 0.9047 - val_loss: 0.2049
# Epoch 21/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 982ms/step - accuracy: 0.9006 - loss: 0.2476
# Epoch 21: val_accuracy improved from 0.92656 to 0.92969, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.9005 - loss: 0.2477 - val_accuracy: 0.9297 - val_loss: 0.1655
# Epoch 22/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 978ms/step - accuracy: 0.8889 - loss: 0.2603
# Epoch 22: val_accuracy did not improve from 0.92969
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.8890 - loss: 0.2602 - val_accuracy: 0.9281 - val_loss: 0.1796
# Epoch 23/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 975ms/step - accuracy: 0.8939 - loss: 0.2498
# Epoch 23: val_accuracy improved from 0.92969 to 0.93125, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.8939 - loss: 0.2497 - val_accuracy: 0.9312 - val_loss: 0.1604
# Epoch 24/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 988ms/step - accuracy: 0.9052 - loss: 0.2425
# Epoch 24: val_accuracy improved from 0.93125 to 0.93281, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 179s 1s/step - accuracy: 0.9052 - loss: 0.2426 - val_accuracy: 0.9328 - val_loss: 0.1569
# Epoch 25/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9126 - loss: 0.2159
# Epoch 25: val_accuracy did not improve from 0.93281
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.9126 - loss: 0.2160 - val_accuracy: 0.9219 - val_loss: 0.1721
# Epoch 26/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9126 - loss: 0.2226
# Epoch 26: val_accuracy did not improve from 0.93281
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 180s 1s/step - accuracy: 0.9125 - loss: 0.2227 - val_accuracy: 0.9312 - val_loss: 0.1554
# Epoch 27/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 987ms/step - accuracy: 0.9048 - loss: 0.2277
# Epoch 27: val_accuracy did not improve from 0.93281
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 180s 1s/step - accuracy: 0.9048 - loss: 0.2277 - val_accuracy: 0.9320 - val_loss: 0.1490
# Epoch 28/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 998ms/step - accuracy: 0.9038 - loss: 0.2271
# Epoch 28: val_accuracy improved from 0.93281 to 0.94453, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.9039 - loss: 0.2271 - val_accuracy: 0.9445 - val_loss: 0.1393
# Epoch 29/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 991ms/step - accuracy: 0.9108 - loss: 0.2150
# Epoch 29: val_accuracy did not improve from 0.94453
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.9108 - loss: 0.2151 - val_accuracy: 0.9430 - val_loss: 0.1424
# Epoch 30/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 991ms/step - accuracy: 0.9135 - loss: 0.2207
# Epoch 30: val_accuracy did not improve from 0.94453
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - accuracy: 0.9136 - loss: 0.2206 - val_accuracy: 0.9430 - val_loss: 0.1545
# Epoch 31/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 980ms/step - accuracy: 0.9058 - loss: 0.2186
# Epoch 31: val_accuracy did not improve from 0.94453
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.9059 - loss: 0.2185 - val_accuracy: 0.9367 - val_loss: 0.1453
# Epoch 32/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 970ms/step - accuracy: 0.9133 - loss: 0.2047
# Epoch 32: val_accuracy did not improve from 0.94453
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.9134 - loss: 0.2047 - val_accuracy: 0.9359 - val_loss: 0.1456
# Epoch 33/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 995ms/step - accuracy: 0.9125 - loss: 0.2061
# Epoch 33: val_accuracy improved from 0.94453 to 0.94609, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - accuracy: 0.9125 - loss: 0.2060 - val_accuracy: 0.9461 - val_loss: 0.1381
# Epoch 34/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 980ms/step - accuracy: 0.9174 - loss: 0.2050
# Epoch 34: val_accuracy did not improve from 0.94609
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - accuracy: 0.9174 - loss: 0.2049 - val_accuracy: 0.9383 - val_loss: 0.1457
# Epoch 35/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 958ms/step - accuracy: 0.9210 - loss: 0.1853
# Epoch 35: val_accuracy did not improve from 0.94609
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0
100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 982ms/step - accuracy: 0.9668 - loss: 0.1012
# Epoch 87: val_accuracy did not improve from 0.97578
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.9668 - loss: 0.1011 - val_accuracy: 0.9641 - val_loss: 0.0977
# Epoch 88/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 977ms/step - accuracy: 0.9685 - loss: 0.0972
# Epoch 88: val_accuracy improved from 0.97578 to 0.97656, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.9685 - loss: 0.0972 - val_accuracy: 0.9766 - val_loss: 0.0707
# Epoch 89/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 967ms/step - accuracy: 0.9686 - loss: 0.0855
# Epoch 89: val_accuracy did not improve from 0.97656
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.9686 - loss: 0.0855 - val_accuracy: 0.9633 - val_loss: 0.1093
# Epoch 90/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 958ms/step - accuracy: 0.9648 - loss: 0.0892
# Epoch 90: val_accuracy did not improve from 0.97656
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.9648 - loss: 0.0892 - val_accuracy: 0.9688 - val_loss: 0.0753
# Epoch 91/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 960ms/step - accuracy: 0.9609 - loss: 0.1053
# Epoch 91: val_accuracy did not improve from 0.97656
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.9610 - loss: 0.1053 - val_accuracy: 0.9750 - val_loss: 0.0726
# Epoch 92/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 957ms/step - accuracy: 0.9631 - loss: 0.1020
# Epoch 92: val_accuracy did not improve from 0.97656
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.9632 - loss: 0.1019 - val_accuracy: 0.9750 - val_loss: 0.0703
# Epoch 93/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 967ms/step - accuracy: 0.9720 - loss: 0.0846
# Epoch 93: val_accuracy did not improve from 0.97656
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.9720 - loss: 0.0846 - val_accuracy: 0.9766 - val_loss: 0.0643
# Epoch 94/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 977ms/step - accuracy: 0.9731 - loss: 0.0896
# Epoch 94: val_accuracy did not improve from 0.97656
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.9731 - loss: 0.0896 - val_accuracy: 0.9742 - val_loss: 0.0640
# Epoch 95/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 977ms/step - accuracy: 0.9716 - loss: 0.0754
# Epoch 95: val_accuracy improved from 0.97656 to 0.97812, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.9716 - loss: 0.0754 - val_accuracy: 0.9781 - val_loss: 0.0617
# Epoch 96/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 983ms/step - accuracy: 0.9680 - loss: 0.0881
# Epoch 96: val_accuracy improved from 0.97812 to 0.98047, saving model to best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.9680 - loss: 0.0881 - val_accuracy: 0.9805 - val_loss: 0.0668
# Epoch 97/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 957ms/step - accuracy: 0.9711 - loss: 0.0842
# Epoch 97: val_accuracy did not improve from 0.98047
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.9711 - loss: 0.0843 - val_accuracy: 0.9672 - val_loss: 0.1039
# Epoch 98/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 960ms/step - accuracy: 0.9655 - loss: 0.0925
# Epoch 98: val_accuracy did not improve from 0.98047
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.9655 - loss: 0.0924 - val_accuracy: 0.9695 - val_loss: 0.0800
# Epoch 99/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 977ms/step - accuracy: 0.9699 - loss: 0.0906
# Epoch 99: val_accuracy did not improve from 0.98047
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.9699 - loss: 0.0906 - val_accuracy: 0.9578 - val_loss: 0.1023
# Epoch 100/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 995ms/step - accuracy: 0.9673 - loss: 0.0904
# Epoch 100: val_accuracy did not improve from 0.98047
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - accuracy: 0.9674 - loss: 0.0903 - val_accuracy: 0.9719 - val_loss: 0.0792

# %%
model = tf.keras.models.load_model('best_model.keras',custom_objects={"RandomSensorDropout": RandomSensorDropout})
test_loss, test_accuracy = model.evaluate(test_ds, verbose=0)
print("test accuracy is ", test_accuracy)
# Out:
# test accuracy is  0.984375
